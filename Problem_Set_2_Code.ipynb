# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeharika-m19/OpenCourseWare_Intro_to_CS_and_Programming_Using_Python/blob/main/Problem_Set_2_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e3ab9b8-04c2-4eea-ba88-7c5cdf4ce605" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e3ab9b8-04c2-4eea-ba88-7c5cdf4ce605">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_filename = "mit6_100l_f22_ps2_code.zip"

with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall("OpenCourseWare_Into_To_Python")  # You can name this anything

# List contents to confirm
print("Extracted files:")
print(os.listdir("OpenCourseWare_Into_To_Python"))
# Out:
# Extracted files:
# ['__MACOSX', '1_ps2']

# %%
with open('OpenCourseWare_Into_To_Python/1_ps2/hangman.py', 'r') as f:
    content = f.read()

print(content)
# Out:
# # Problem Set 2, hangman.py
# # Name:
# # Collaborators:
# # Time spent:
#
# import random
# import string
#
# # -----------------------------------
# # HELPER CODE
# # -----------------------------------
#
# WORDLIST_FILENAME = "words.txt"
#
# def load_words():
#     """
#     returns: list, a list of valid words. Words are strings of lowercase letters.
#
#     Depending on the size of the word list, this function may
#     take a while to finish.
#     """
#     print("Loading word list from file...")
#     # inFile: file
#     inFile = open(WORDLIST_FILENAME, 'r')
#     # line: string
#     line = inFile.readline()
#     # wordlist: list of strings
#     wordlist = line.split()
#     print(" ", len(wordlist), "words loaded.")
#     return wordlist
#
# def choose_word(wordlist):
#     """
#     wordlist (list): list of words (strings)
#
#     returns: a word from wordlist at random
#     """
#     return random.choice(wordlist)
#
# # -----------------------------------
# ...

# %%
import random
import string

WORDLIST_FILENAME = "OpenCourseWare_Into_To_Python/1_ps2/words.txt"

def load_words():
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print(" ", len(wordlist), "words loaded.")
    return wordlist
def choose_word(wordlist):
    return random.choice(wordlist)

wordlist = load_words()

def has_player_won(secret_word, letters_guessed):
    return all(letter in letters_guessed for letter in secret_word)

def get_word_progress(secret_word, letters_guessed):
    return ''.join(letter if letter in letters_guessed else '*' for letter in secret_word)

def get_available_letters(letters_guessed):
    all_letters = string.ascii_lowercase
    return ''.join(letter for letter in all_letters if letter not in letters_guessed)

def hangman(secret_word, with_help=False):
    print("Welcome to Hangman!")
    print(f"I am thinking of a word that is {len(secret_word)} letters long.")

    guesses_remaining = 10
    letters_guessed = []
    vowels = set('aeiou')

    while guesses_remaining > 0:
        print("-" * 14)
        print(f"You have {guesses_remaining} guesses left.")
        available = get_available_letters(letters_guessed)
        print(f"Available letters: {available}")

        guess = input("Please guess a letter: ").lower()

        if guess == '!' and with_help:
            if guesses_remaining < 3:
                print(f"Oops! Not enough guesses left: {get_word_progress(secret_word, letters_guessed)}")
                continue

            # Find an unguessed letter from secret_word
            unguessed = [letter for letter in secret_word if letter in available]
            if unguessed:
                revealed = random.choice(unguessed)
                print(f"Letter revealed: {revealed}")
                letters_guessed.append(revealed)
                guesses_remaining -= 3
                print(get_word_progress(secret_word, letters_guessed))
                if has_player_won(secret_word, letters_guessed):
                    break
                continue
            else:
                print("No more letters to reveal!")
                continue

        # Validate input
        if not guess.isalpha() or len(guess) != 1:
            print("Oops! That is not a valid letter. Please input a letter from the alphabet:",
                  get_word_progress(secret_word, letters_guessed))
            continue

        # Check if letter was already guessed
        if guess in letters_guessed:
            print(f"Oops! You've already guessed that letter: {get_word_progress(secret_word, letters_guessed)}")
            continue

        letters_guessed.append(guess)

        if guess in secret_word:
            print(f"Good guess: {get_word_progress(secret_word, letters_guessed)}")
        else:
            print(f"Oops! That letter is not in my word: {get_word_progress(secret_word, letters_guessed)}")
            # Deduct guesses based on vowel/consonant
            if guess in vowels:
                guesses_remaining -= 2
            else:
                guesses_remaining -= 1

        if has_player_won(secret_word, letters_guessed):
            break

    # Game end
    print("-" * 14)
    if has_player_won(secret_word, letters_guessed):
        unique_letters = len(set(secret_word))
        score = guesses_remaining * unique_letters
        print("Congratulations, you won!")
        print(f"Your total score for this game is: {score}")
    else:
        print(f"Sorry, you ran out of guesses. The word was {secret_word}.")
#To Test
secret_word = choose_word(wordlist)
with_help = False
hangman(secret_word, with_help)
# Out:
# Loading word list from file...
#   55900 words loaded.
# Welcome to Hangman!
# I am thinking of a word that is 9 letters long.
# --------------
# You have 10 guesses left.
# Available letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Oops! That letter is not in my word: *********
# --------------
# You have 8 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: e
# Good guess: *****e***
# --------------
# You have 8 guesses left.
# Available letters: bcdfghijklmnopqrstuvwxyz
# Please guess a letter: i
# Oops! That letter is not in my word: *****e***
# --------------
# You have 6 guesses left.
# Available letters: bcdfghjklmnopqrstuvwxyz
# Please guess a letter: o
# Good guess: *o*o*e***
# --------------
# You have 6 guesses left.
# Available letters: bcdfghjklmnpqrstuvwxyz
# Please guess a letter: b
# Oops! That letter is not in my word: *o*o*e***
# --------------
# You have 5 guesses left.
# Available letters: cdfghjklmnpqrstuvwxyz
# ...

# %%
#To Test
secret_word = choose_word(wordlist)
with_help = True
hangman(secret_word, with_help)
# Out:
# Welcome to Hangman!
# I am thinking of a word that is 8 letters long.
# --------------
# You have 10 guesses left.
# Available letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Oops! That letter is not in my word: ********
# --------------
# You have 8 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: !
# Letter revealed: h
# ****h***
# --------------
# You have 5 guesses left.
# Available letters: bcdefgijklmnopqrstuvwxyz
# Please guess a letter: !
# Letter revealed: i
# *i**hi**
# --------------
# You have 2 guesses left.
# Available letters: bcdefgjklmnopqrstuvwxyz
# Please guess a letter: !
# Oops! Not enough guesses left: *i**hi**
# --------------
# You have 2 guesses left.
# Available letters: bcdefgjklmnopqrstuvwxyz
# Please guess a letter: e
# Good guess: *i**hie*
# --------------
# You have 2 guesses left.
# Available letters: bcdfgjklmnopqrstuvwxyz
# Please guess a letter: n
# Oops! That letter is not in my word: *i**hie*
# ...

# %%
#To Test
secret_word = choose_word(wordlist)
with_help = True
hangman(secret_word, with_help)
# Out:
# Welcome to Hangman!
# I am thinking of a word that is 10 letters long.
# --------------
# You have 10 guesses left.
# Available letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter: !
# Letter revealed: a
# ***a**a***
# --------------
# You have 7 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Oops! You've already guessed that letter: ***a**a***
# --------------
# You have 7 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: @
# Oops! That is not a valid letter. Please input a letter from the alphabet: ***a**a***
# --------------
# You have 7 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: 3
# Oops! That is not a valid letter. Please input a letter from the alphabet: ***a**a***
# --------------
# You have 7 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: i
# Oops! That letter is not in my word: ***a**a***
# --------------
# ...
